# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from pathlib import Path
import pandas as pd

DRIVE_PATH = Path("/content/drive/MyDrive/ColabNotebooks/FinalProject/hh_vacancies_dataset.csv")

def load_dataset():
    if DRIVE_PATH.exists():
        return pd.read_csv(DRIVE_PATH)

    from google.colab import files

    uploaded = files.upload()
    if len(uploaded) == 0:
        raise RuntimeError("Файл не загружен. Повторите загрузку.")

    filename = next(iter(uploaded.keys()))
    return pd.read_csv(filename)

df = load_dataset()
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (21709, 20)
#           id              published_at  \
# 0  125985240  2026-01-20T13:39:32+0300
# 1  129646053  2026-01-20T12:14:51+0300
# 2  129662670  2026-01-20T15:23:34+0300
# 3  112625062  2026-01-20T08:14:58+0300
# 4  129667398  2026-01-20T16:19:41+0300
#
#                                                 name  area_id area_name  \
# 0                               Пикер на электрокаре        1    Москва
# 1                                            Сварщик        1    Москва
# 2  Администратор салона красоты (на запись клиентов)        1    Москва
# 3                            Помощник Волан-де-Морта        1    Москва
# 4                               Frontend-разработчик        1    Москва
#
#    employer_id                 employer_name  salary_from  salary_to  \
# 0    5756414.0  Журавлев Александр Сергеевич       7500.0     8571.0
# 1    4316103.0                 PROFF MONTAGE     145000.0   185000.0
# 2    4965012.0                 Грейс Солюшнс      40000.0    80000.0
# 3    1087973.0       ГРУППА КОМПАНИЙ ПРОСТОР     255000.0   355000.0
# 4    3365485.0       НПЦ СпецЭлектронСистемы     150000.0   200000.0
#
#   salary_currency salary_gross    experience employment schedule  \
# 0             RUR        False  noExperience       part  fullDay
# 1             RUR        False  between1And3       full  fullDay
# 2             RUR        False  noExperience       full   remote
# 3             RUR        False  noExperience       full  fullDay
# 4             RUR        False  between1And3       full  fullDay
#
#      professional_role_main    professional_roles_all  \
# 0                 Кладовщик                 Кладовщик
# 1                   Сварщик                   Сварщик
# 2             Администратор             Администратор
# 3     Агент по недвижимости     Агент по недвижимости
# 4  Программист, разработчик  Программист, разработчик
#
#                                           key_skills  key_skills_count  \
# 0  Электротележка, Электрокара, Пикер, Сборщик, К...                 8
# 1  Сварочные работы, Сварщик, Сварка металлоконст...                10
# 2  Телефонные переговоры, Ведение переписки, Навы...                10
# 3  Выявление потребностей, Грамотная устная речь,...                11
# 4                                                NaN                 0
#
#                                          description  \
# 0  <p><em>Срочно требуются начинающие и опытные п...
# 1  <p>В компанию на постоянную работу требуется с...
# 2  <p><strong>&quot;Нежно&quot; - Московская сеть...
# 3  <p><strong>НЕ ЗНАЕШЬ С ЧЕГО НАЧАТЬ? НАЧНИ С ПР...
# 4  <p>В IT-отдел требуется <strong>Программист fr...
#
#                      alternate_url
# 0  https://hh.ru/vacancy/125985240
# 1  https://hh.ru/vacancy/129646053
# 2  https://hh.ru/vacancy/129662670
# 3  https://hh.ru/vacancy/112625062
# 4  https://hh.ru/vacancy/129667398

# %%
print("Пропуски (доля):")
display(df.isna().mean().sort_values(ascending=False).head(15))

print("Дубликаты по id:", df["id"].duplicated().sum())
# Out:
# Пропуски (доля):
# salary_to                 0.582201
# key_skills                0.411995
# salary_from               0.363029
# salary_currency           0.305035
# salary_gross              0.305035
# employer_id               0.009489
# published_at              0.000000
# id                        0.000000
# area_id                   0.000000
# name                      0.000000
# employer_name             0.000000
# area_name                 0.000000
# experience                0.000000
# employment                0.000000
# professional_role_main    0.000000
# dtype: float64
# Дубликаты по id: 0

# %%
df["id"] = df["id"].astype(str)

df["published_at"] = pd.to_datetime(df["published_at"], errors="coerce")

df = df.drop_duplicates(subset=["id"]).reset_index(drop=True)

print("Shape after dedup:", df.shape)
# Out:
# Shape after dedup: (21709, 20)

# %%
import re
import html

TAG_RE = re.compile(r"<[^>]+>")

EMOJI_RE = re.compile(
    "["
    "\U0001F600-\U0001F64F"
    "\U0001F300-\U0001F5FF"
    "\U0001F680-\U0001F6FF"
    "\U0001F1E0-\U0001F1FF"
    "\U00002700-\U000027BF"
    "\U0001FA70-\U0001FAFF"
    "]+",
    flags=re.UNICODE
)

def clean_text(text: str) -> str:
    if pd.isna(text):
        return ""
    text = str(text)
    text = html.unescape(text)
    text = TAG_RE.sub(" ", text)
    text = EMOJI_RE.sub(" ", text)
    text = text.replace("\xa0", " ")
    text = re.sub(r"[^0-9A-Za-zА-Яа-яЁё\s\.\,\:\;\!\?\-\+\#\/\(\)]", " ", text)
    text = re.sub(r"\s+", " ", text).strip().lower()
    return text

df["name_clean"] = df["name"].fillna("").astype(str).str.strip().str.lower()
df["description_clean"] = df["description"].apply(clean_text)
df["text_full"] = (df["name_clean"] + " " + df["description_clean"]).str.strip()
df["name_len"] = df["name_clean"].str.len()
df["desc_len"] = df["description_clean"].str.len()
df["text_len"] = df["text_full"].str.len()

# %%
import numpy as np
import pandas as pd

df["salary_mid"] = np.where(
    df["salary_from"].notna() & df["salary_to"].notna(),
    (df["salary_from"] + df["salary_to"]) / 2,
    np.where(df["salary_from"].notna(), df["salary_from"], df["salary_to"])
)
df.loc[df["salary_gross"] == True, "salary_mid"] *= 0.87

df_salary = df[df["salary_mid"].notna()].copy()

df_salary = df_salary[df_salary["salary_currency"].isin(["RUR", "RUB"])].copy()

df_salary = df_salary[df_salary["salary_mid"] > 0].copy()

print(df_salary.shape)
# Out:
# (14899, 27)

# %%
df = df.rename(columns={"salary_gross": "salary_was_gross"})
df_salary = df_salary.rename(columns={"salary_gross": "salary_was_gross"})

# %%
q = df_salary["salary_mid"].quantile([0.95, 0.99, 0.995])
print("\nКвантили salary_mid:")
display(q)
# Out:
# Квантили salary_mid:
# 0.950    270000.0
# 0.990    500000.0
# 0.995    637750.0
# Name: salary_mid, dtype: float64

# %%
df_salary.sort_values("salary_mid").head(10)[
    ["salary_mid", "salary_from", "salary_to", "salary_currency", "name", "employer_name", "alternate_url"]
]
# Out:
#        salary_mid  salary_from  salary_to salary_currency  \
# 7550        1.305          1.0        2.0             RUR
# 14397       2.000          2.0        NaN             RUR
# 21112      50.000         50.0        NaN             RUR
# 18076      80.000         80.0        NaN             RUR
# 19844     200.000        200.0        NaN             RUR
# 11129     200.000          NaN      200.0             RUR
# 10740     250.000        250.0        NaN             RUR
# 11980     250.000        250.0        NaN             RUR
# 4416      261.000        300.0        NaN             RUR
# 11338     290.000        250.0      330.0             RUR
#
#                                                     name  \
# 7550                                    Аналитик ведущий
# 14397                             Зубной техник керамист
# 21112                                         Кастелянша
# 18076                                      Офис-менеджер
# 19844  Помощник менеджера проектов (маркетинговые исс...
# 11129                       Frontend-разработчик (React)
# 10740        SMM-менеджер в нише образования (Instagram)
# 11980                                            Бариста
# 4416                                    Контент-менеджер
# 11338                         Администратор фитнес-клуба
#
#                                            employer_name  \
# 7550                                          Ростелеком
# 14397                      Федяевский Дмитрий Викторович
# 21112  ФГАОУ ВО Первый МГМУ им. И.М.Сеченова Минздрав...
# 18076                                      Школьная Лига
# 19844                           Минькова Анна Васильевна
# 11129                                             Morizo
# 10740                                            Yfizika
# 11980                          Шаронова Ксения Борисовна
# 4416                          Алексеева Дарья Николаевна
# 11338                                    Джим Про Реутов
#
#                          alternate_url
# 7550   https://hh.ru/vacancy/129797172
# 14397  https://hh.ru/vacancy/129976266
# 21112  https://hh.ru/vacancy/130087343
# 18076  https://hh.ru/vacancy/130037391
# 19844  https://hh.ru/vacancy/130069358
# 11129  https://hh.ru/vacancy/129929854
# 10740  https://hh.ru/vacancy/129892107
# 11980  https://hh.ru/vacancy/129923164
# 4416   https://hh.ru/vacancy/129747177
# 11338  https://hh.ru/vacancy/129928137

# %%
for thr in [10000, 20000, 30000, 40000]:
    cnt = (df_salary["salary_mid"] < thr).sum()
    share = cnt / len(df_salary)
    print(f"< {thr:>6}: {cnt:>5} вакансий ({share:.2%})")
# Out:
# <  10000:   490 вакансий (3.29%)
# <  20000:   565 вакансий (3.79%)
# <  30000:   651 вакансий (4.37%)
# <  40000:   825 вакансий (5.54%)

# %%
df_salary.loc[df_salary["salary_mid"] < 30000, "salary_mid"].describe()
# Out:
# count      651.000000
# mean      7963.387181
# std       7397.803443
# min          1.305000
# 25%       3500.000000
# 50%       5000.000000
# 75%       9450.000000
# max      29705.280000
# Name: salary_mid, dtype: float64

# %%
HIGH_SALARY = df_salary["salary_mid"].quantile(0.99)
LOW_SALARY = 30000

print("Порог снизу:", LOW_SALARY)
print("Порог сверху (99-й перцентиль):", int(HIGH_SALARY))

before = len(df_salary)
df_salary = df_salary[df_salary["salary_mid"].between(LOW_SALARY, HIGH_SALARY)].copy()
after = len(df_salary)

print("Строк до фильтра:", before)
print("Строк после фильтра:", after)
print("Удалено:", before - after, f"({(before - after)/before:.2%})")
# Out:
# Порог снизу: 30000
# Порог сверху (99-й перцентиль): 500000
# Строк до фильтра: 14899
# Строк после фильтра: 14131
# Удалено: 768 (5.15%)

# %%
df_salary["salary_has_from"] = df_salary["salary_from"].notna().astype(int)
df_salary["salary_has_to"] = df_salary["salary_to"].notna().astype(int)

# %%
cat_cols = ["experience", "employment", "schedule", "professional_role_main"]

for col in cat_cols:
    df_salary[col] = df_salary[col].fillna("unknown").astype(str)

# %%
df_salary["key_skills_count"] = (
    pd.to_numeric(df_salary["key_skills_count"], errors="coerce")
    .fillna(0)
    .astype(int)
)

# %%
df_salary["pub_dow"] = df_salary["published_at"].dt.dayofweek

# %%
print("Итоговая форма датасета:", df_salary.shape)
df_salary.head()
# Out:
# Итоговая форма датасета: (14131, 30)
#           id              published_at  \
# 1  129646053 2026-01-20 12:14:51+03:00
# 2  129662670 2026-01-20 15:23:34+03:00
# 3  112625062 2026-01-20 08:14:58+03:00
# 4  129667398 2026-01-20 16:19:41+03:00
# 5  129641722 2026-01-20 11:26:28+03:00
#
#                                                 name  area_id area_name  \
# 1                                            Сварщик        1    Москва
# 2  Администратор салона красоты (на запись клиентов)        1    Москва
# 3                            Помощник Волан-де-Морта        1    Москва
# 4                               Frontend-разработчик        1    Москва
# 5                     Специалист по документообороту        1    Москва
#
#    employer_id            employer_name  salary_from  salary_to  \
# 1    4316103.0            PROFF MONTAGE     145000.0   185000.0
# 2    4965012.0            Грейс Солюшнс      40000.0    80000.0
# 3    1087973.0  ГРУППА КОМПАНИЙ ПРОСТОР     255000.0   355000.0
# 4    3365485.0  НПЦ СпецЭлектронСистемы     150000.0   200000.0
# 5     742469.0             ФК ЛОКОМОТИВ          NaN   120000.0
#
#   salary_currency  ...                                         name_clean  \
# 1             RUR  ...                                            сварщик
# 2             RUR  ...  администратор салона красоты (на запись клиентов)
# 3             RUR  ...                            помощник волан-де-морта
# 4             RUR  ...                               frontend-разработчик
# 5             RUR  ...                     специалист по документообороту
#
#                                    description_clean  \
# 1  в компанию на постоянную работу требуется свар...
# 2  нежно - московская сеть салонов лазерной эпиля...
# 3  не знаешь с чего начать? начни с простора! ком...
# 4  в it-отдел требуется программист frontend (jav...
# 5  обязанности: организация систематизированного ...
#
#                                            text_full name_len desc_len  \
# 1  сварщик в компанию на постоянную работу требуе...        7      515
# 2  администратор салона красоты (на запись клиент...       49     1116
# 3  помощник волан-де-морта не знаешь с чего начат...       23     2031
# 4  frontend-разработчик в it-отдел требуется прог...       20      572
# 5  специалист по документообороту обязанности: ор...       30     1635
#
#   text_len salary_mid  salary_has_from salary_has_to pub_dow
# 1      523   165000.0                1             1       1
# 2     1166    60000.0                1             1       1
# 3     2055   305000.0                1             1       1
# 4      593   175000.0                1             1       1
# 5     1666   104400.0                0             1       1
#
# [5 rows x 30 columns]

# %%
from pathlib import Path

FULL_NAME = "hh_vacancies_clean_full.parquet"
SALARY_NAME = "hh_vacancies_salary_model.parquet"

DRIVE_DIR = Path("/content/drive/MyDrive/ColabNotebooks/FinalProject/ProcessedDatasets")

def save_parquets(df_full, df_salary):
    if DRIVE_DIR.exists():
        DRIVE_DIR.mkdir(parents=True, exist_ok=True)

        full_path = DRIVE_DIR / FULL_NAME
        salary_path = DRIVE_DIR / SALARY_NAME

        df_full.to_parquet(full_path, index=False)
        df_salary.to_parquet(salary_path, index=False)

        return str(full_path), str(salary_path)

    local_dir = Path("/content")
    full_path = local_dir / FULL_NAME
    salary_path = local_dir / SALARY_NAME

    df_full.to_parquet(full_path, index=False)
    df_salary.to_parquet(salary_path, index=False)

    from google.colab import files
    files.download(str(full_path))
    files.download(str(salary_path))

    return str(full_path), str(salary_path)

save_parquets(df, df_salary)
# Out:
# ('/content/drive/MyDrive/ColabNotebooks/FinalProject/ProcessedDatasets/hh_vacancies_clean_full.parquet',
#  '/content/drive/MyDrive/ColabNotebooks/FinalProject/ProcessedDatasets/hh_vacancies_salary_model.parquet')
